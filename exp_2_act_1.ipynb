# %%
speed=float(input("Enter vehical speed(in km/h): "))
if speed >60:
    print("You are overspeeding! Fine will be applied.")
else:print("You are within the speed limit. Drive safely.")
# Out:
# Enter vehical speed(in km/h): 50
# You are within the speed limit. Drive safely.
