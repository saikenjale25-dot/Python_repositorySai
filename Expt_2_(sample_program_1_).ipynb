# %%
year=int(input("Enter year:"))
if(year%400==0)or(year%4==0and year%100!=0):
   print("Leap Year")
else:
    print("not a leap year")
# Out:
# <>:2: SyntaxWarning: invalid decimal literal
# <>:2: SyntaxWarning: invalid decimal literal
# /tmp/ipykernel_9285/1775845617.py:2: SyntaxWarning: invalid decimal literal
#   if(year%400==0)or(year%4==0and year%100!=0):
# Enter year:2024
# Leap Year
