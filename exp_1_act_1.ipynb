# %%
#Program to display name,address,and age

name = "Sai Pankaj Kenjale"
address = "At Post Koregaon, Satara"
age = "19"

print("Name:", name)
print("Address:", address)
print("Age:", age)
# Out:
# Name: Sai Pankaj Kenjale
# Address: At Post Koregaon, Satara
# Age: 19
