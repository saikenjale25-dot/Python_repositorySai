# %%
age=int(input("Enter your age:"))
if age>=18:
    print("You are eligible to enter the movie.")
else:
    print("Sorry, you are not eligible to enter.")
# Out:
# Enter your age:20
# You are eligible to enter the movie.
