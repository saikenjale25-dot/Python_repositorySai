# %%
f = open("report.txt","w")
f.write("this is a simple report file")
f.close()

f = open("report.txt","r")
text = f.read()
word = text.split()
print("number of word:", len(word))
f.close()
# Out:
# number of word: 6
