# %%
n=int(input("Enter number:"))
fact=1
for i in range(1,n+1):
  fact=fact*i
  print("Factorial:",fact)
# Out:
# Enter number:5
# Factorial: 1
# Factorial: 2
# Factorial: 6
# Factorial: 24
# Factorial: 120
